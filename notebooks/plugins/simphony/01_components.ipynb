# %% [markdown]
# # Simphony circuit simulator
#
# [Simphony](https://simphonyphotonics.readthedocs.io/en/latest/) is a circuit simulator based on [scikit-rf](https://scikit-rf.readthedocs.io/en/latest/)
#
# The main advantage of simphony over [SAX](https://flaport.github.io/sax/) is that simphony works in Windows, Linux and MacOs. While SAX only works on MacOs and Linux.
#
# It also supports the SiEPIC PDK library natively.
#
# ## Component models
#
# You can use component models from :
#
# - Sparameters from Lumerical FDTD simulations thanks to the gdsfactory Lumerical plugin
# - [SiPANN](https://sipann.readthedocs.io/en/latest/?badge=latest) open source package

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdsfactory as gf

import gdsfactory.simulation.simphony as gs
import gdsfactory.simulation.simphony.components as gc
# Out:
# 2022-11-07 00:14:17.936 | INFO     | gdsfactory.config:<module>:45 - Load '/home/runner/work/gdsfactory/gdsfactory/gdsfactory' 5.54.0
# 2022-11-07 00:14:19.222844: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-07 00:14:19.262420: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-07 00:14:20.060610: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-07 00:14:20.060840: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-07 00:14:20.060862: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_GAP/model
# 2022-11-07 00:14:22.049999: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-07 00:14:22.050055: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_GAP/model
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_STRAIGHT/model
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_STRAIGHT/model
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_BENT_RAND/model
# INFO:tensorflow:Restoring parameters from /usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/SiPANN/ANN/TIGHT_ANGLE_BENT_RAND/model

# %%
c = gf.components.mzi()
n = c.get_netlist()

# %%
c
# Out:
# mzi: uid e9bc3a79, ports ['o1', 'o2'], references ['cp1', 'cp2', 'bend_euler_1', 'syl', 'bend_euler_2', 'sxb', 'bend_euler_3', 'sytl', 'bend_euler_4', 'sxt', 'bend_euler_5', 'bend_euler_6', 'straight_5', 'straight_6', 'straight_7', 'bend_euler_7', 'bend_euler_8', 'straight_8', 'straight_9', 'straight_10'], 0 polygons

# %%
c.plot_netlist()

# %% [markdown]
# ### Straight
#
# Lets start with the Sparameter model of a straight waveguide.
#
# The models are for lossless elements.

# %%
m = gc.straight()
wavelengths = np.linspace(1500, 1600, 128) * 1e-9
gs.plot_model(m, logscale=False, wavelengths=wavelengths)
# Out:
# 2022-11-07 00:14:23.745 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
m = gc.straight()
wavelengths = np.linspace(1500, 1600, 128) * 1e-9
gs.plot_model(m, phase=True, wavelengths=wavelengths)
# Out:
# 2022-11-07 00:14:23.902 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='angle (rad)'>

# %% [markdown]
# ### Bend

# %%
m = gc.bend_circular(radius=2)  # this bend should have some loss
gs.plot_model(m, logscale=False, wavelengths=wavelengths)
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
m = gc.mmi1x2()  # this model comes from Lumerical FDTD 3D sims
gs.plot_model(m, pin_in="o1")
# Out:
# 2022-11-07 00:14:24.216 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.mmi1x2()  # this model comes from Lumerical FDTD 3D sims
gs.plot_model(m, pin_in="o1", pins=["o2", "o3"])
# Out:
# 2022-11-07 00:14:24.423 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.mmi1x2()
gs.plot_model(m, pin_in="o1", phase=True)
# Out:
# 2022-11-07 00:14:24.610 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='angle (rad)'>

# %%
m.pins
# Out:
# [<simphony.pins.Pin at 0x7f047aa1c580>,
#  <simphony.pins.Pin at 0x7f050d4843a0>,
#  <simphony.pins.Pin at 0x7f0469e01640>]

# %%
pin = m.pins[0]

# %% [markdown]
# As you can see the MMI has -20dB reflection and -3dB transmission

# %%
gs.plot_model(m, pins=("o2", "o3"))
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.mmi2x2()  # this model comes from Lumerical FDTD 3D sims
gs.plot_model(m)
# Out:
# 2022-11-07 00:14:25.045 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi2x2_b9bb9ff2.dat
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
gs.plot_model(m, pins=("o3", "o4"))
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.coupler_ring()
gs.plot_model(m, logscale=False, wavelengths=wavelengths)
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
gc.coupler_ring?

# %%
m = gc.coupler_ring(gap=0.3)
gs.plot_model(m, logscale=False, wavelengths=wavelengths)
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
m = gc.coupler(gap=0.3)
gs.plot_model(m, logscale=False, wavelengths=wavelengths)
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
m = gc.gc1550te()
gs.plot_model(m, logscale=True, pin_in="port 1")
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.gc1550te()
gs.plot_model(m, logscale=True, pin_in="port 1")
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %%
m = gc.gc1550te()
gs.plot_model(m, logscale=False, pin_in="port 1")
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %% [markdown]
# ## Circuit simulations
#
# With Simphony you can also combine components into circuits
#
# ### MZI interferometer

# %%
import matplotlib.pyplot as plt
import gdsfactory.simulation.simphony as gs
import gdsfactory.simulation.simphony.components as gc
import gdsfactory as gf

# %%
c = gf.components.mzi(delta_length=10)
c
# Out:
# mzi_delta_length10: uid a4ea7857, ports ['o1', 'o2'], references ['cp1', 'cp2', 'bend_euler_1', 'syl', 'bend_euler_2', 'sxb', 'bend_euler_3', 'sytl', 'bend_euler_4', 'sxt', 'bend_euler_5', 'bend_euler_6', 'straight_5', 'straight_6', 'straight_7', 'bend_euler_7', 'bend_euler_8', 'straight_8', 'straight_9', 'straight_10'], 0 polygons

# %%
c.plot_netlist()

# %%
circuit = gs.components.mzi(delta_length=10, splitter=gs.components.mmi1x2)

gs.plot_circuit(
    circuit,
    start=1500e-9,
    stop=1600e-9,
    logscale=True,
)
# Out:
# 2022-11-07 00:14:27.070 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:27.089 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:27.107 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:14:27.110 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
circuit = gs.components.mzi(delta_length=100, splitter=gs.components.mmi1x2)

gs.plot_circuit(
    circuit,
    start=1500e-9,
    stop=1600e-9,
    logscale=True,
)
# Out:
# 2022-11-07 00:14:39.143 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:39.162 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:39.181 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:14:39.184 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %% [markdown]
# Lets add grating couplers to the mzi circuit.

# %%
mzi_layout = gf.components.mzi(delta_length=100)
mzi_with_gc_layout = gf.routing.add_fiber_single(
    component=mzi_layout, with_loopback=False
)
mzi_with_gc_layout
# Out:
# mzi_delta_length100_mov_3be5b5ae: uid d105faf3, ports ['vertical_te_00', 'vertical_te_1'], references ['move_1', 'straight_1', 'straight_2', 'grating_coupler_elliptical_trenches_1', 'grating_coupler_elliptical_trenches_2'], 0 polygons

# %%
c = gc.gc1550te()
gs.plot_model(c, pin_in="port 1")
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S (dB)|'>

# %% [markdown]
# ### MZI interferometer from layout

# %%
import gdsfactory as gf
import gdsfactory.simulation.simphony as gs
import gdsfactory.simulation.simphony.components as gc
from simphony.libraries import siepic

c = gf.components.mzi(delta_length=10)
c
# Out:
# mzi_delta_length10: uid a4ea7857, ports ['o1', 'o2'], references ['cp1', 'cp2', 'bend_euler_1', 'syl', 'bend_euler_2', 'sxb', 'bend_euler_3', 'sytl', 'bend_euler_4', 'sxt', 'bend_euler_5', 'bend_euler_6', 'straight_5', 'straight_6', 'straight_7', 'bend_euler_7', 'bend_euler_8', 'straight_8', 'straight_9', 'straight_10'], 0 polygons

# %%
cm = gs.component_to_circuit(c)
gs.plot_circuit(cm)
# Out:
# 2022-11-07 00:14:52.363 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:52.381 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:14:52.401 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.403 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.406 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.408 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.410 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.412 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:14:52.414 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:14:52.416 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:14:52.418 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:14:52.420 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
c = gf.components.mzi(
    delta_length=20
)  # Double the delta length should reduce FSR by half
cm = gs.component_to_circuit(c)
# Out:
# 2022-11-07 00:15:06.443 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:15:06.461 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:15:06.478 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.480 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.482 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.484 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.487 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.490 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys(['cross_section'])
# 2022-11-07 00:15:06.493 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:15:06.496 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:15:06.499 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:15:06.501 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])

# %%
gs.plot_circuit(cm)
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %% [markdown]
# ### Ring resonator

# %%
c = gf.components.ring_double(radius=5)
c
# Out:
# ring_double_radius5: uid c1e536be, ports ['o1', 'o2', 'o3', 'o4'], references ['coupler_ring_1', 'coupler_ring_2', 'straight_1', 'straight_2'], 0 polygons

# %%
c = gc.ring_double(radius=5)
gs.plot_circuit(c, pins_out=["o2", "o3", "o4"])
# Out:
# 2022-11-07 00:15:20.575 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:15:20.579 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# /home/runner/work/gdsfactory/gdsfactory/gdsfactory/simulation/simphony/plot_circuit.py:64: RuntimeWarning: divide by zero encountered in log10
#   y = 10 * np.log10(y) if logscale else y
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
c = gf.components.ring_double(radius=10)  # double radius, reduces FSR by half.
c
# Out:
# ring_double_radius10: uid ef34f4fa, ports ['o1', 'o2', 'o3', 'o4'], references ['coupler_ring_1', 'coupler_ring_2', 'straight_1', 'straight_2'], 0 polygons

# %%
c = gs.components.ring_double(radius=10)
gs.plot_circuit(c, pins_out=["o2", "o3", "o4"])
# Out:
# 2022-11-07 00:15:57.143 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:15:57.146 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %%
c = gf.components.ring_single(radius=5)
c
# Out:
# ring_single_radius5: uid db3bfbac, ports ['o2', 'o1'], references ['coupler_ring_1', 'straight_1', 'straight_2', 'bend_euler_1', 'bend_euler_2', 'straight_3'], 0 polygons

# %%
c = gs.components.ring_single(radius=10)
gs.plot_circuit(c, pins_out=["o2"])
# Out:
# <AxesSubplot: xlabel='wavelength (nm)', ylabel='|S|'>

# %% [markdown]
# ## Montecarlo variability simulation
#
# As you define your circuit models you can also include the standard deviation for each component model.
#
# For example for the waveguide model you can define:
#
# ```
# sigma_ne: Standard deviation of the effective index for monte carlo simulations (default 0.05).
# sigma_ng: Standard deviation of the group velocity for monte carlo simulations
# sigma_nd: Standard deviation of the group dispersion for monte carlo simulations
# ```
#
# And you can pass `runs` to change the number of Monte Carlo iterations to run.
#
# The variability values are foundry specific and they relate to the width and sigma variations from the fabrication process.

# %%
circuit = gs.components.mzi(delta_length=10)

gs.plot_circuit_montecarlo(circuit, runs=10)
# Out:
# 2022-11-07 00:16:40.211 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:16:40.229 | INFO     | gdsfactory.simulation.lumerical.read:read_sparameters_lumerical:129 - Sparameters loaded from /home/runner/work/gdsfactory/gdsfactory/gdslib/sp/mmi1x2_b9bb9ff2.dat
# 2022-11-07 00:16:40.248 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
# 2022-11-07 00:16:40.251 | INFO     | gdsfactory.simulation.simphony.components.straight:straight:23 - ignoring dict_keys([])
