# %% [markdown]
# # Tidy3D mode solver
#
# ## Waveguides

# %%
import gdsfactory.simulation.gtidy3d as gt

nm = 1e-3
# Out:
# 2022-11-07 00:17:44.769 | INFO     | gdsfactory.config:<module>:45 - Load '/home/runner/work/gdsfactory/gdsfactory/gdsfactory' 5.54.0
# [00:17:46] INFO     Using client version: 1.7.1                                                      ]8;id=612623;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py\__init__.py]8;;\:]8;id=620935;file:///usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d/__init__.py#95\95]8;;\
# 2022-11-07 00:17:47.020 | INFO     | gdsfactory.simulation.gtidy3d:<module>:54 - Tidy3d '1.7.1' installed at ['/usr/share/miniconda/envs/anaconda-client-env/lib/python3.9/site-packages/tidy3d']

# %%
strip = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
strip.plot_index()

# %%
strip.plot_Ex(0)  # TE
strip.plot_Ey(1)  # TM
# Out:
# 2022-11-07 00:17:47.371 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.

# %%
rib = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.15,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
rib.plot_index()

# %%
rib.plot_Ex(mode_index=0)
rib.plot_Ey(mode_index=0)
# Out:
# 2022-11-07 00:17:48.476 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bf8ecbd9.npz mode data from file cache.

# %%
nitride = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=1.0,
    wg_thickness=0.4,
    slab_thickness=0.0,
    ncore=gt.modes.sin,
    nclad=gt.modes.sio2,
)
nitride.plot_index()
nitride.plot_Ex(0)
nitride.plot_Ey(0)
# Out:
# 2022-11-07 00:17:49.460 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7b92a943.npz mode data from file cache.

# %% [markdown]
# ## Sweep width
#
# You can sweep the waveguide width and compute the modes.

# %%
df = gt.modes.sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
gt.modes.plot_sweep_width(
    width1=200 * nm,
    width2=1000 * nm,
    steps=11,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2022-11-07 00:17:50.284 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cbc69aad.npz mode data from file cache.
# 2022-11-07 00:17:50.401 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d88e531c.npz mode data from file cache.
# 2022-11-07 00:17:50.515 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bfe27829.npz mode data from file cache.
# 2022-11-07 00:17:50.626 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/b604ff01.npz mode data from file cache.
# 2022-11-07 00:17:50.737 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6453e781.npz mode data from file cache.
# 2022-11-07 00:17:50.851 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/701c0cac.npz mode data from file cache.
# 2022-11-07 00:17:50.966 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5d807a39.npz mode data from file cache.
# 2022-11-07 00:17:51.074 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/36d898bf.npz mode data from file cache.
# 2022-11-07 00:17:51.192 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/af7059be.npz mode data from file cache.
# 2022-11-07 00:17:51.311 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa2134a5.npz mode data from file cache.
# 2022-11-07 00:17:51.421 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/3daa332f.npz mode data from file cache.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2022-11-07 00:17:51.533 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cbc69aad.npz mode data from file cache.
# 2022-11-07 00:17:51.640 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d88e531c.npz mode data from file cache.
# 2022-11-07 00:17:51.731 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/

#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2.733264</td>
#       <td>0.997805</td>
#       <td>2.405998</td>
#       <td>0.985437</td>
#       <td>1.995796</td>
#       <td>0.034885</td>
#       <td>1.814504</td>
#       <td>0.909442</td>
#       <td>1.00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Group index
#
# You can also compute the group index for a waveguide.

# %%
import gdsfactory.simulation.gtidy3d as gt
import numpy as np
import matplotlib.pyplot as plt

nm = 1e-3

ng = gt.modes.group_index(
    wg_width=500 * nm,
    wavelength=1.55,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)
print(ng)
# Out:
# 2022-11-07 00:17:53.222 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-11-07 00:17:53.325 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9632c7cb.npz mode data from file cache.
# 2022-11-07 00:17:53.428 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ee6112c0.npz mode data from file cache.
# 4.16956337679879

# %%
wavelengths = np.arange(1500, 1601, 50) * 1e-3
wg_widths = np.arange(400, 601, 50) * 1e-3

wg_settings = dict(
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)

for wg_width in wg_widths:
    ng = [
        gt.modes.group_index(wavelength=wavelength, wg_width=wg_width, **wg_settings)
        for wavelength in wavelengths
    ]
    plt.plot(wavelengths, ng, label=f"{wg_width*1e3}")

plt.legend()
plt.xlabel("Wavelength (um)")
plt.xlabel("ng")
# Out:
# 2022-11-07 00:17:53.543 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/6f4d3cd7.npz mode data from file cache.
# 2022-11-07 00:17:53.646 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bd4c384f.npz mode data from file cache.
# 2022-11-07 00:17:53.746 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/28144d52.npz mode data from file cache.
# 2022-11-07 00:17:53.855 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/17e81e4c.npz mode data from file cache.
# 2022-11-07 00:17:53.962 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c2bb5e05.npz mode data from file cache.
# 2022-11-07 00:17:54.061 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8be1b1b4.npz mode data from file cache.
# 2022-11-07 00:17:54.170 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9a215eee.npz mode data from file cache.
# 2022-11-07 00:17:54.276 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e4329efe.npz mode data from file cache.
# 2022-11-07 00:17:54.375 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/42f10c0c.npz mode data from file cache.
# 2022-11-07 00:17:54.495 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/13844833.npz mode data from file cache.
# 2022-11-07 00:17:54.602 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/4e8484ba.npz mode data from file cache.
# 2022-11-07 00:17:54.720 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9429b40d.npz mode data from file cache.
# 2022-11-07 00:17:54.831 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be624d43.npz mode data from file cache.
# 2022-11-07 00:17:54.935 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cc1549de.npz mode data from file cache.
# 2022-11-07 00:17:55.043 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/79a1d52e.npz mode data from file cache.
# 2022-11-07 00:17:55.153 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/0046583f.npz mode data from file cache.
# 2022-11-07 00:17:55.260 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/a9d652ff.npz mode data from file cache.
# 2022-11-07 00:17:55.371 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/0df605d6.npz mode data from file cache.
# 2022-11-07 00:17:55.480 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e386d28f.npz mode data from file cache.
# 2022-11-07 00:17:55.583 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/5bc85921.npz mode data from file cache.
# 2022-11-07 00:17:55.686 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/93f207d3.npz mode data from file cache.
# 2022-11-07 00:17:55.769 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-11-07 00:17:55.849 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/9632c7cb.npz mode data from file cache.
# 2022-11-07 00:17:55.927 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ee6112c0.npz mode data from file cache.
# 2022-11-07 00:17:56.037 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/730b850d.npz mode data from file cache.
# 2022-11-07 00:17:56.142 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/de3be3b3.npz mode data from file cache.
# 2022-11-07 00:17:56.254 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c1d14568.npz mode data from file cache.
# 2022-11-07 00:17:56.364 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/78d2303d.npz mode data from file cache.
# 2022-11-07 00:17:56.480 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa0d1b7e.npz mode data from file cache.
# 2022-11-07 00:17:56.579 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/e7777089.npz mode data from file cache.
# 2022-11-07 00:17:56.687 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/4396a926.npz mode data from file cache.
# 2022-11-07 00:17:56.787 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/59d4d6e4.npz mode data from file cache.
# 2022-11-07 00:17:56.889 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/dbfb2068.npz mode data from file cache.
# 2022-11-07 00:17:56.992 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7f20089a.npz mode data from file cache.
# 2022-11-07 00:17:57.101 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/f3af4332.npz mode data from file cache.
# 2022-11-07 00:17:57.203 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/31bfd079.npz mode data from file cache.
# 2022-11-07 00:17:57.309 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/2c3f68f8.npz mode data from file cache.
# 2022-11-07 00:17:57.420 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aed7cd02.npz mode data from file cache.
# 2022-11-07 00:17:57.526 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/d0502b59.npz mode data from file cache.
# 2022-11-07 00:17:57.643 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/08714841.npz mode data from file cache.
# 2022-11-07 00:17:57.746 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/aa2338ad.npz mode data from file cache.
# 2022-11-07 00:17:57.851 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/7b03094d.npz mode data from file cache.
# 2022-11-07 00:17:57.957 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/bd533f85.npz mode data from file cache.
# 2022-11-07 00:17:58.061 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/fa9c95e6.npz mode data from file cache.
# 2022-11-07 00:17:58.167 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/23bfd82a.npz mode data from file cache.

# %% [markdown]
# ## Bend modes
#
# You can compute bend modes specifying the bend radius.

# %%
strip_bend = gt.modes.Waveguide(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    bend_radius=3,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
)

# %%
# lets plot the fundamental TE mode
strip_bend.plot_Ex(0)
strip_bend.plot_Ey(0)
# Out:
# 2022-11-07 00:17:58.492 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be958cac.npz mode data from file cache.

# %%
# lets plot the fundamental TM mode
strip_bend.plot_Ex(1)
strip_bend.plot_Ey(1)

# %% [markdown]
# ## Bend loss
#
# You can also compute the losses coming from the mode mismatch from the bend into a straight waveguide.
# To compute the bend loss due to mode mismatch you can calculate the mode overlap of the straight mode and the bent mode.
# Because there are two mode mismatch interfaces the total loss due to mode mismatch will be squared (from bend to straight and from straight to bend).
#
# ![](https://i.imgur.com/M1Yysdr.png)
#
# [from paper](https://ieeexplore.ieee.org/ielaam/50/8720127/8684870-aam.pdf)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

r, integral = gt.modes.sweep_bend_loss(
    wavelength=1.55,
    wg_width=0.5,
    wg_thickness=0.22,
    slab_thickness=0.0,
    ncore=gt.modes.si,
    nclad=gt.modes.sio2,
    bend_radius_min=2.0,
    bend_radius_max=5,
    steps=4,
    mode_index=0,
)

plt.plot(r, integral, ".")
plt.xlabel("bend radius (um)")
plt.ylabel("Transmission")
plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2022-11-07 00:18:00.180 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/534e038e.npz mode data from file cache.
# 2022-11-07 00:18:00.288 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/cdf8a2c5.npz mode data from file cache.
# 2022-11-07 00:18:00.382 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/be958cac.npz mode data from file cache.
# 2022-11-07 00:18:00.488 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/8c18cbe1.npz mode data from file cache.
# 2022-11-07 00:18:00.598 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/ba280765.npz mode data from file cache.

# %% [markdown]
# ## Waveguide coupler
#
# You can also compute the modes of a waveguide coupler.
#
# ```
#         wg_width1     wg_width2
#         <------->     <------->
#          _______   |   _______   __
#         |       |  |  |       | |
#         |       |  |  |       | |
#         |       |_____|       | | wg_thickness
#         |slab_thickness       | |
#         |_____________________| |__
#                 <----->
#                   gap
#
#
# ```

# %%
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=100 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2022-11-07 00:18:02.135 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:532 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/71a54018.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
c.plot_Ex(0)
# Out:
# 2022-11-07 00:18:04.114 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:532 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c25e802a.npz mode data to file cache.

# %%
c.plot_Ex(1)

# %%
import gdsfactory.simulation.gtidy3d as gt
import matplotlib.pyplot as plt

# %%
nm = 1e-3
si = gt.modes.si
sio2 = gt.modes.sio2
c = gt.modes.WaveguideCoupler(
    wavelength=1.55,
    wg_width1=500 * nm,
    wg_width2=500 * nm,
    gap=200 * nm,
    wg_thickness=220 * nm,
    slab_thickness=0 * nm,
    ncore=si,
    nclad=sio2,
)
c.plot_index()

# %%
gaps = [150, 200, 250, 300]
coupling_length = [
    gt.modes.WaveguideCoupler(
        wavelength=1.55,
        wg_width1=500 * nm,
        wg_width2=500 * nm,
        gap=gap * nm,
        wg_thickness=220 * nm,
        slab_thickness=0 * nm,
        ncore=si,
        nclad=sio2,
    ).find_coupling(power_ratio=1)
    for gap in gaps
]
# Out:
# 2022-11-07 00:18:06.615 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:532 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c4549e4b.npz mode data to file cache.
# 2022-11-07 00:18:06.640 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:367 - load /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/c25e802a.npz mode data from file cache.
# 2022-11-07 00:18:07.767 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:532 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/2988cb26.npz mode data to file cache.
# 2022-11-07 00:18:08.648 | INFO     | gdsfactory.simulation.gtidy3d.modes:compute_modes:532 - write /home/runner/work/gdsfactory/gdsfactory/gdslib/modes/35a09f1f.npz mode data to file cache.

# %%
plt.plot(gaps, coupling_length, ".")
plt.xlabel("gap (nm)")
plt.ylabel("100% coupling length (um)")
